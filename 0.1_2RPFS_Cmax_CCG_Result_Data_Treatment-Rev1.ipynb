# %% [markdown]
# ## 2RPFS Problem (Cmax objective) - Data treatment of result files

# %%
import pandas as pd
import numpy as np
import os, fnmatch
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
import glob
import os

# %matplotlib inline

# %%
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %% [markdown]
# ### List files in the output folder

# %%
rootfolder = os.getcwd()
file_list = glob.glob(os.path.join(rootfolder, 'output', '*.csv'), recursive=False)
file_list
# Out:
# ['/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_10 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-3.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-4.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs_a40_RB1004005.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_150 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_150 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_20 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-3.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-4.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-5.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a10_RB2003010.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_04_05_06.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004007.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004008.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004009.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004010.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a50_RB2005003.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_50 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_50 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_10 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_100 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_150 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_20 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-3.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-4.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-5.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_50 jobs-2.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_50 jobs.csv']

# %%
extra_file_list = glob.glob(os.path.join(rootfolder, 'output', 'extra', '*.csv'), recursive=False)
extra_file_list
# Out:
# ['/public/doutorado_files/2RPFS_Cmax_Budget/output/extra/RB1502008_n150_results.csv',
#  '/public/doutorado_files/2RPFS_Cmax_Budget/output/extra/RB2005010_n200_results.csv']

# %% [markdown]
# ### Read all the CSV files

# %%
# Alternative script to treat files with incorrect number of coluns or faulty lines
def alternative_csv_reader(filename, delimiter=',', header=0, names=None):
    with open(filename, 'r') as file:
        lines = file.readlines() 
        count = 1
        line_list = []
        num_columns = 20
        for line in lines:  # Strips the newline character 
            #print("line{}: {}".format(count, line.strip())) 
            nc = len(line.split(','))
            if 'executionId,' in line:
                #num_columns = nc
                print('Detected {0} columns in CSV file.'.format(nc))
            else:
                if 'none,' in line:
                    if nc == num_columns:
                        line_list.append(line)
                    elif nc > num_columns:  # treat strange truncated lines
                        line = line[line.rfind('none,'):]
                        nc = len(line.split(','))
                        if nc == num_columns:
                            print('WARN: truncating line {0}, for having more columns than expected.'.format(count))
                            line_list.append(line)
                        else:
                            print('WARN: Ignoring line {0}, since it has {1} columns, instead of {2}: '.format(count, nc, num_columns), line)
                    else:  # Ignore line
                        print('WARN: Ignoring line {0}: '.format(count), line)    
                elif len(line_list[-1].split(',')) < num_columns:  # current line is a continuation of the previous one
                    line_list[-1] = line_list[-1].replace('\n', '') + line
                    print('*** Treated line {0}: '.format(count), line_list[-1])
                else:  # Ignore line
                    print('WARN: Ignoring line {0}: '.format(count), line)
            count += 1
        # assert all lines have the same number of columns
        count = 1
        for line in line_list:
            nc = len(line.split(','))
            if nc != num_columns:
                print('ERROR: Line {0} has {1} columns, instead of {2}: '.format(count, nc, num_columns), line)
            count += 1
        text_data = StringIO(''.join(line_list))
        #print('line_list: ', str(line_list))
        #print('text_data: ', text_data)
        df = pd.read_csv(text_data, delimiter=delimiter, header=header, names=names)
        return df

# %% [markdown]
# ### Process all CSV files and append all data to a single dataframe (one per solution method: Wilson, Wagner)

# %%
# %%time

df_wilson = pd.DataFrame()
df_wagner = pd.DataFrame()
for filename in file_list:
    print('Processing file ', filename)
    try:
        df_ = pd.read_csv(filename, delimiter=',', header=0, names=['executionId','ub_name','instance_name','alpha','n','m','budget_Gamma','cmax','permutation','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','is_optimal','validated','gap','lb','cost','cmax_dp'])
    except:  # try alternative method to read csv lines
        df_ = alternative_csv_reader(filename, delimiter=',', header=0, names=['executionId','ub_name','instance_name','alpha','n','m','budget_Gamma','cmax','permutation','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','is_optimal','validated','gap','lb','cost','cmax_dp'])
    if 'wagner' not in filename:  # Wilson result file
        df_wilson = df_wilson.append(df_.copy())
    else:  # Wagner result file
        df_wagner = df_wagner.append(df_.copy())
# Out:
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_10 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-2.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-3.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs-4.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_100 jobs_a40_RB1004005.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_150 jobs-2.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_150 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_20 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-2.csv
# Detected 20 columns in CSV file.
# Detected 20 columns in CSV file.
# Detected 20 columns in CSV file.
# Detected 20 columns in CSV file.
# WARN: truncating line 190, for having more columns than expected.
# WARN: truncating line 191, for having more columns than expected.
# WARN: Ignoring line 193:  42 174 117 200 53 123 133 7 88 190 127 36 52 166 98 76 131 140 138 93 79 184 68 141 62 185 2 78 110 44 125 81 163 167 120 48 179 191 154 109 160 156 114 22 171 90 84 116 143 57 94 34 152 40 71 150 108 9 113 175 176 173 54 18 149 180 6 169 96 128 92 1 8 60 59 100 107 28 38 89 61 161 115 97 136 74 56 122 63 187 69 172 20 86 41 129 158 35 80 112 142 188 130 104 55 19 159 178 51 182 10 85 11 39 145 148 105 95 134 14 43 27 189 49 168 75 72 23 37 193 13 147 164 82 66 162 29 195 47 135 65 15 33 181 58 102 196 126 170 186 155 153 32 46 3 45 192 24 26 16 25 70, 1070.15077332, 1070.15077332, 4, 4, 3, true, true, 0.0, 9247.5, 9247.5, 9247.5
#
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-3.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-4.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs-5.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a10_RB2003010.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_04_05_06.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004007.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004008.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004009.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a40_RB2004010.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_200 jobs_a50_RB2005003.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_50 jobs-2.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_50 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_10 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_100 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_150 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_20 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-2.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-3.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-4.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs-5.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_200 jobs.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_50 jobs-2.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/separation_wagner_50 jobs.csv
# CPU times: user 748 ms, sys: 95.4 ms, total: 844 ms
# Wall time: 1.52 s

# %%
df_wagner
# Out:
#     executionId          ub_name   instance_name alpha   n  m budget_Gamma  \
# 0          none   mip_separation   RB0103001.txt    10  10  2        20 20
# 1          none   mip_separation   RB0103001.txt    10  10  2        20 40
# 2          none   mip_separation   RB0103001.txt    10  10  2        20 60
# 3          none   mip_separation   RB0103001.txt    10  10  2        20 80
# 4          none   mip_separation   RB0103001.txt    10  10  2       20 100
# ..          ...              ...             ...   ...  .. ..          ...
# 995        none   mip_separation   RB0505010.txt    50  50  2       100 20
# 996        none   mip_separation   RB0505010.txt    50  50  2       100 40
# 997        none   mip_separation   RB0505010.txt    50  50  2       100 60
# 998        none   mip_separation   RB0505010.txt    50  50  2       100 80
# 999        none   mip_separation   RB0505010.txt    50  50  2      100 100
#
#        cmax                                        permutation time_spent  \
# 0     285.1                               10 9 7 5 3 4 2 6 1 8    6.33528
# 1     285.1                               10 9 2 4 1 7 6 5 3 8   0.109844
# 2     285.1                               10 1 2 4 3 7 9 5 6 8  0.0807145
# 3     285.1                               10 2 7 5 9 6 3 4 1 8  0.0552768
# 4     285.1                               10 1 2 7 5 4 9 6 3 8  0.0566595
# ..      ...                                                ...        ...
# 995    2196   30 2 40 33 18 29 8 35 37 25 36 24 17 19 21 20...    6.62297
# 996    2196   37 24 29 18 27 50 42 31 38 47 21 6 2 46 7 48 ...    1.65574
# 997    2196   20 8 48 37 39 46 19 9 41 34 49 29 45 33 42 44...    1.43077
# 998    2196   20 11 39 7 3 14 47 42 17 50 9 15 31 40 46 49 ...    1.29878
# 999  2212.5   20 2 1 35 37 30 38 41 9 10 11 29 16 4 45 27 2...   0.377379
#
#     time_to_best_sol iterations num_visited_solutions num_improvements  \
# 0            6.33528          2                     2                1
# 1           0.109844          4                     4                3
# 2          0.0807145          3                     3                2
# 3          0.0552768          3                     3                2
# 4          0.0566595          3                     3                2
# ..               ...        ...                   ...              ...
# 995          6.62297         11                    11               10
# 996          1.65574          5                     5                4
# 997          1.43077          4                     4                3
# 998          1.29878          4                     4                3
# 999         0.377379          2                     2                1
#
#     is_optimal validated          gap      lb    cost cmax_dp
# 0         true      true            0   285.1   285.1   285.1
# 1         true      true -1.99381e-16   285.1   285.1   285.1
# 2         true      true -1.99381e-16   285.1   285.1   285.1
# 3         true      true            0   285.1   285.1   285.1
# 4         true      true  1.99381e-16   285.1   285.1   285.1
# ..         ...       ...          ...     ...     ...     ...
# 995       true      true            0    2196    2196    2196
# 996       true      true            0    2196    2196    2196
# 997       true      true            0    2196    2196    2196
# 998       true      true            0    2196    2196    2196
# 999       true      true            0  2212.5  2212.5  2212.5
#
# [7509 rows x 20 columns]

# %%
df_wagner['instance_name'] = df_wagner['instance_name'].str.strip()

# %%
# Remove 2RPFS results for instances 
#df_wagner = df_wagner[(df_wagner['instance_name'] != 'RB2005010.txt') & (df_wagner['instance_name'] != 'RB1502008.txt')]
for filename in extra_file_list:
    print('Processing file ', filename)
    try:
        df_ = pd.read_csv(filename, delimiter=';', header=0, names=['executionId','ub_name','instance_name','alpha','n','m','budget_Gamma','cmax','permutation','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','is_optimal','validated','gap','lb','cost','cmax_dp','cut_count'])
    except:  # try alternative method to read csv lines
        df_ = alternative_csv_reader(filename, delimiter=';', header=0, names=['executionId','ub_name','instance_name','alpha','n','m','budget_Gamma','cmax','permutation','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','is_optimal','validated','gap','lb','cost','cmax_dp','cut_count'])
    df_wagner = df_wagner.append(df_.copy())
# Out:
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/extra/RB1502008_n150_results.csv
# Processing file  /public/doutorado_files/2RPFS_Cmax_Budget/output/extra/RB2005010_n200_results.csv

# %%
df_wagner
# Out:
#    executionId          ub_name  instance_name alpha    n  m budget_Gamma  \
# 0         none   mip_separation  RB0103001.txt    10   10  2        20 20
# 1         none   mip_separation  RB0103001.txt    10   10  2        20 40
# 2         none   mip_separation  RB0103001.txt    10   10  2        20 60
# 3         none   mip_separation  RB0103001.txt    10   10  2        20 80
# 4         none   mip_separation  RB0103001.txt    10   10  2       20 100
# ..         ...              ...            ...   ...  ... ..          ...
# 21        none   mip_separation  RB2005010.txt    50  200  2       100 20
# 22        none   mip_separation  RB2005010.txt    50  200  2       100 40
# 23        none   mip_separation  RB2005010.txt    50  200  2       100 60
# 24        none   mip_separation  RB2005010.txt    50  200  2       100 80
# 25        none   mip_separation  RB2005010.txt    50  200  2      100 100
#
#      cmax                                        permutation time_spent  ...  \
# 0   285.1                               10 9 7 5 3 4 2 6 1 8    6.33528  ...
# 1   285.1                               10 9 2 4 1 7 6 5 3 8   0.109844  ...
# 2   285.1                               10 1 2 4 3 7 9 5 6 8  0.0807145  ...
# 3   285.1                               10 2 7 5 9 6 3 4 1 8  0.0552768  ...
# 4   285.1                               10 1 2 7 5 4 9 6 3 8  0.0566595  ...
# ..    ...                                                ...        ...  ...
# 21   9192  14 2 186 83 5 6 197 155 160 22 131 133 13 9 98...    1507.53  ...
# 22   9192  14 2 186 83 5 6 197 155 160 22 131 133 13 9 98...    945.762  ...
# 23   9192  14 2 186 83 5 6 197 155 160 22 131 133 13 9 98...    45.3002  ...
# 24   9192  14 2 186 83 5 6 197 155 160 22 131 133 13 9 98...    105.885  ...
# 25   9192  14 2 186 83 5 6 197 155 160 22 131 133 13 9 98...    13.4063  ...
#
#    iterations num_visited_solutions num_improvements is_optimal validated  \
# 0           2                     2                1       true      true
# 1           4                     4                3       true      true
# 2           3                     3                2       true      true
# 3           3                     3                2       true      true
# 4           3                     3                2       true      true
# ..        ...                   ...              ...        ...       ...
# 21         12                    12               11       True      True
# 22          9                     9                8       True      True
# 23          5                     5                4       True      True
# 24          5                     5                4       True      True
# 25          2                     2                1       True      True
#
#             gap     lb   cost cmax_dp cut_count
# 0             0  285.1  285.1   285.1       NaN
# 1  -1.99381e-16  285.1  285.1   285.1       NaN
# 2  -1.99381e-16  285.1  285.1   285.1       NaN
# 3             0  285.1  285.1   285.1       NaN
# 4   1.99381e-16  285.1  285.1   285.1       NaN
# ..          ...    ...    ...     ...       ...
# 21            0   9192   9192    9192      11.0
# 22            0   9192   9192    9192       8.0
# 23            0   9192   9192    9192       4.0
# 24            0   9192   9192    9192       4.0
# 25            0   9192   9192    9192       1.0
#
# [7560 rows x 21 columns]

# %% [markdown]
# ### Remove duplicated header rows from both dataframes

# %%
def find_invalid_values(df):
    all_invalid_values = set()
    for col in df:
        if col not in ['executionId','ub_name','instance_name','budget_Gamma','permutation','is_optimal','validated']:
            # 'alpha','n','m','cmax','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','gap','lb','cost','cmax_dp'
            a = pd.to_numeric(df[col], errors='coerce')
            idx = a.isna()
            invalid_values = df.loc[idx][col].unique()
            all_invalid_values.update(invalid_values)
        #elif col in ['is_optimal','validated']
    print('Invalid values:', all_invalid_values)
    return all_invalid_values

# %%
find_invalid_values(df_wagner)
# Out:
# Invalid values: {'alpha', nan, 'lb', 'time_spent', 'cmax', 'cost', 'gap', 'num_visited_solutions', 'time_to_best_sol', 'cmax_dp', 'n', 'm', 'iterations', 'num_improvements'}
# {'alpha',
#  'cmax',
#  'cmax_dp',
#  'cost',
#  'gap',
#  'iterations',
#  'lb',
#  'm',
#  'n',
#  nan,
#  'num_improvements',
#  'num_visited_solutions',
#  'time_spent',
#  'time_to_best_sol'}

# %%
def filter_invalid_values(df):
    # IMPORTANT: AVOID FILTERING 'NAN' VALUES
    for invalid_value in find_invalid_values(df):
        if isinstance(invalid_value, str):  # Evita filtrar os nan
            df = df[~(df == invalid_value).any(axis=1)]
    return df

# %%
df_wilson = filter_invalid_values(df_wilson)
find_invalid_values(df_wilson)
# Out:
# Invalid values: {'alpha', 'lb', 'time_spent', 'cmax', 'cost', 'gap', 'num_visited_solutions', 'time_to_best_sol', 'cmax_dp', 'n', 'm', 'iterations', 'num_improvements'}
# Invalid values: set()
# set()

# %%
df_wagner = filter_invalid_values(df_wagner)
find_invalid_values(df_wagner)
# Out:
# Invalid values: {'alpha', nan, 'lb', 'time_spent', 'cmax', 'cost', 'gap', 'num_visited_solutions', 'time_to_best_sol', 'cmax_dp', 'n', 'm', 'iterations', 'num_improvements'}
# Invalid values: {nan}
# {nan}

# %% [markdown]
# ### Convert column types from object

# %%
def convert_column_types(df):
    for col in df:
        if col in ['alpha','n','m','cmax','time_spent','time_to_best_sol','iterations','num_visited_solutions','num_improvements','gap','lb','cost','cmax_dp']:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        elif col in ['is_optimal','validated']:
            df[col] = df[col].astype('bool')
    return df

# %%
# %%time
df_wilson = convert_column_types(df_wilson)
df_wagner = convert_column_types(df_wagner)
df_wagner.dtypes
# Out:
# CPU times: user 247 ms, sys: 7.15 ms, total: 254 ms
# Wall time: 488 ms
# executionId               object
# ub_name                   object
# instance_name             object
# alpha                      int64
# n                          int64
# m                          int64
# budget_Gamma              object
# cmax                     float64
# permutation               object
# time_spent               float64
# time_to_best_sol         float64
# iterations                 int64
# num_visited_solutions      int64
# num_improvements           int64
# is_optimal                  bool
# validated                   bool
# gap                      float64
# lb                       float64
# cost                     float64
# cmax_dp                  float64
# cut_count                float64
# dtype: object

# %% [markdown]
# ### Trim existing string columns

# %%
def trim_all_columns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)

# %%
df_wilson = trim_all_columns(df_wilson)
df_wagner = trim_all_columns(df_wagner)

# %% [markdown]
# ### Include a column with the name of the underlying C&CG MILP Model

# %%
df_wilson['model'] = 'Wilson'
df_wagner['model'] = 'Wagner'

# %% [markdown]
# ### Concatenate dataframes

# %%
df = df_wilson.append(df_wagner)
df.head(4)
# Out:
#   executionId         ub_name  instance_name  alpha   n  m budget_Gamma  \
# 0        none  mip_separation  RB0103001.txt     10  10  2        20 20
# 1        none  mip_separation  RB0103001.txt     10  10  2        20 40
# 2        none  mip_separation  RB0103001.txt     10  10  2        20 60
# 3        none  mip_separation  RB0103001.txt     10  10  2        20 80
#
#     cmax           permutation  time_spent  ...  num_visited_solutions  \
# 0  285.1  10 1 2 3 5 6 7 9 4 8    5.479829  ...                      3
# 1  285.1  1 10 7 4 2 3 6 5 9 8    0.076683  ...                      3
# 2  285.1  1 10 9 7 2 3 4 6 5 8    0.078870  ...                      3
# 3  285.1  10 1 2 9 4 5 3 7 6 8    0.078112  ...                      3
#
#    num_improvements  is_optimal  validated           gap     lb   cost  \
# 0                 2        True       True -1.993806e-16  285.1  285.1
# 1                 2        True       True  0.000000e+00  285.1  285.1
# 2                 2        True       True  0.000000e+00  285.1  285.1
# 3                 2        True       True  0.000000e+00  285.1  285.1
#
#    cmax_dp   model  cut_count
# 0    285.1  Wilson        NaN
# 1    285.1  Wilson        NaN
# 2    285.1  Wilson        NaN
# 3    285.1  Wilson        NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# ### Split the column budget_Gamma into Gamma1 and Gamma2

# %%
# new data frame with split value columns 
new = df["budget_Gamma"].str.split(" ", n = 1, expand = True) 
# making separate first name column from new data frame 
df["Gamma1"]= new[0] 
# making separate last name column from new data frame 
df["Gamma2"]= new[1] 
# convert Gamma columns to numeric
df["Gamma1"] = pd.to_numeric(df["Gamma1"], errors='coerce')
df["Gamma2"] = pd.to_numeric(df["Gamma2"], errors='coerce')
df = df.replace(np.nan, -100, regex=True)
df["Gamma1"] = df["Gamma1"].astype(int)
df["Gamma2"] = df["Gamma2"].astype(int)
df["n"] = df["n"].astype(int)
df["m"] = df["m"].astype(int)
df["alpha"] = df["alpha"].astype(int)

# %% [markdown]
# ### Fix instance names
#
# The original instance names, as provided by Ying in the instance file zip, were assembled incorrectly.
#
# The problem lies in the alpha percentage. We are now going to fix this issue.

# %%
df['seq'] = df['instance_name'].str[7:9]
df['n_str'] = df['n'].astype(str).str.zfill(3)
df['alpha_str'] = df['alpha'].astype(str)

# %%
df['instance_name'] = 'RB' + df['n_str'] + df['alpha_str'] + df['seq'] + '.txt'
df.drop(columns=['n_str', 'alpha_str'], inplace=True)

# %% [markdown]
# ### Filter paper instance results (n=150 and n=200)

# %%
len(df.index)
# Out:
# 15416

# %%
df[(df['cut_count'] < 0)&(df['instance_name'] == 'RB2005010.txt')]
# Out:
#     executionId         ub_name  instance_name  alpha    n  m budget_Gamma  \
# 90         none  mip_separation  RB2005010.txt     50  200  2        20 20
# 91         none  mip_separation  RB2005010.txt     50  200  2        20 40
# 92         none  mip_separation  RB2005010.txt     50  200  2        20 60
# 93         none  mip_separation  RB2005010.txt     50  200  2        20 80
# 94         none  mip_separation  RB2005010.txt     50  200  2       20 100
# 95         none  mip_separation  RB2005010.txt     50  200  2        40 20
# 96         none  mip_separation  RB2005010.txt     50  200  2        40 40
# 97         none  mip_separation  RB2005010.txt     50  200  2        40 60
# 98         none  mip_separation  RB2005010.txt     50  200  2        40 80
# 99         none  mip_separation  RB2005010.txt     50  200  2       40 100
# 100        none  mip_separation  RB2005010.txt     50  200  2        60 20
# 101        none  mip_separation  RB2005010.txt     50  200  2        60 40
# 102        none  mip_separation  RB2005010.txt     50  200  2        60 60
# 103        none  mip_separation  RB2005010.txt     50  200  2        60 80
# 104        none  mip_separation  RB2005010.txt     50  200  2       60 100
# 105        none  mip_separation  RB2005010.txt     50  200  2        80 20
# 106        none  mip_separation  RB2005010.txt     50  200  2        80 40
# 107        none  mip_separation  RB2005010.txt     50  200  2        80 60
# 108        none  mip_separation  RB2005010.txt     50  200  2        80 80
# 109        none  mip_separation  RB2005010.txt     50  200  2       80 100
# 110        none  mip_separation  RB2005010.txt     50  200  2       100 20
# 111        none  mip_separation  RB2005010.txt     50  200  2       100 40
# 112        none  mip_separation  RB2005010.txt     50  200  2       100 60
# 113        none  mip_separation  RB2005010.txt     50  200  2       100 80
# 114        none  mip_separation  RB2005010.txt     50  200  2      100 100
# 0          none  mip_separation  RB2005010.txt     50  200  2        20 20
# 1          none  mip_separation  RB2005010.txt     50  200  2        20 40
# 2          none  mip_separation  RB2005010.txt     50  200  2        20 60
# 3          none  mip_separation  RB2005010.txt     50  200  2        20 80
# 4          none  mip_separation  RB2005010.txt     50  200  2       20 100
# 5          none  mip_separation  RB2005010.txt     50  200  2        40 20
# 6          none  mip_separation  RB2005010.txt     50  200  2        40 40
# 7          none  mip_separation  RB2005010.txt     50  200  2        40 60
# 8          none  mip_separation  RB2005010.txt     50  200  2        40 80
# 9          none  mip_separation  RB2005010.txt     50  200  2       40 100
# 10         none  mip_separation  RB2005010.txt     50  200  2        60 20
# 11         none  mip_separation  RB2005010.txt     50  200  2        60 40
# 12         none  mip_separation  RB2005010.txt     50  200  2        60 60
# 13         none  mip_separation  RB2005010.txt     50  200  2        60 80
# 14         none  mip_separation  RB2005010.txt     50  200  2       60 100
# 15         none  mip_separation  RB2005010.txt     50  200  2        80 20
# 16         none  mip_separation  RB2005010.txt     50  200  2        80 40
# 17         none  mip_separation  RB2005010.txt     50  200  2        80 60
# 18         none  mip_separation  RB2005010.txt     50  200  2        80 80
# 19         none  mip_separation  RB2005010.txt     50  200  2       80 100
# 20         none  mip_separation  RB2005010.txt     50  200  2       100 20
# 21         none  mip_separation  RB2005010.txt     50  200  2       100 40
# 22         none  mip_separation  RB2005010.txt     50  200  2       100 60
# 23         none  mip_separation  RB2005010.txt     50  200  2       100 80
# 24         none  mip_separation  RB2005010.txt     50  200  2      100 100
#
#        cmax                                        permutation    time_spent  \
# 90   7205.5  73 27 150 60 83 96 113 177 184 48 158 148 109 ...   7600.929033
# 91   7743.0  73 27 150 60 83 96 113 177 184 48 158 148 109 ...   7452.786222
# 92   8350.0  73 27 150 60 83 96 113 177 184 48 158 148 109 ...   8187.741883
# 0    ...       True  0.020047  7033.5  -500.0   7174.5  Wagner     -100.0
# 1    ...       True  0.012703  7636.0  -500.0   7733.0  Wagner     -100.0
# 2    ...       True  0.000600  8334.5  8339.5   8339.5  Wagner     -100.0
# 3    ...       True  0.000000  8754.0  8754.0   8754.0  Wagner     -100.0
# 4    ...       True  0.000000  9022.5  9022.5   9022.5  Wagner     -100.0
# 5    ...       True  0.045790  7720.0  -500.0   8073.5  Wagner     -100.0
# 6    ...       True  0.061846  7640.0  -500.0   8112.5  Wagner     -100.0
# 7    ...       True  0.000600  8334.5  8339.5   8339.5  Wagner     -100.0
# 8    ...       True  0.000000  8754.0  8754.0   8754.0  Wagner     -100.0
# 9    ...       True  0.000000  9022.5  9022.5   9022.5  Wagner     -100.0
# 10   ...       True  0.025288  8383.5  -500.0   8595.5  Wagner     -100.0
# 11   ...       True  0.065655  8240.0  -500.0   8781.0  Wagner     -100.0
# 12   ...       True  0.045518  8183.5  -500.0   8556.0  Wagner     -100.0
# 13   ...       True  0.000000  8754.0  8754.0   8754.0  Wagner     -100.0
# 14   ...       True  0.000000  9022.5  9022.5   9022.5  Wagner     -100.0
# 15   ...       True  0.017154  8832.0  -500.0   8983.5  Wagner     -100.0
# 16   ...       True  0.011516  8813.5  8915.0   8915.0  Wagner     -100.0
# 17   ...       True  0.026696  8728.0  -500.0   8961.0  Wagner     -100.0
# 18   ...       True  0.000562  8891.5  -500.0   8896.5  Wagner     -100.0
# 19   ...       True  0.000000  9022.5  9022.5   9022.5  Wagner     -100.0
# 20   ...       True  0.000000  9192.0  9192.0   9192.0  Wagner     -100.0
# 21   ...       True  0.000000  9192.0  9192.0   9192.0  Wagner     -100.0
# 22   ...       True  0.000000  9192.0  9192.0   9192.0  Wagner     -100.0
# 23   ...       True  0.000000  9192.0  9192.0   9192.0  Wagner     -100.0
# 24   ...       True  0.000000  9192.0  9192.0   9192.0  Wagner     -100.0
#
#      Gamma1  Gamma2  seq
# 90       20      20   10
# 91       20      40   10
# 92       20      60   10
# 93       20      80   10
# 94       20     100   10
# 95       40      20   10
# 96       40      40   10
# 97       40      60   10
# 98       40      80   10
# 99       40     100   10
# 100      60      20   10
# 101      60      40   10
# 102      60      60   10
# 103      60      80   10
# 104      60     100   10
# 105      80      20   10
# 106      80      40   10
# 107      80      60   10
# 108      80      80   10
# 109      80     100   10
# 110     100      20   10
# 111     100      40   10
# 112     100      60   10
# 113     100      80   10
# 114     100     100   10
# 0        20      20   10
# 1        20      40   10
# 2        20      60   10
# 3        20      80   10
# 4        20     100   10
# 5        40      20   10
# 6        40      40   10
# 7        40      60   10
# 8        40      80   10
# 9        40     100   10
# 10       60      20   10
# 11       60      40   10
# 12       60      60   10
# 13       60      80   10
# 14       60     100   10
# 15       80      20   10
# 16       80      40   10
# 17       80      60   10
# 18       80      80   10
# 19       80     100   10
# 20      100      20   10
# 21      100      40   10
# 22      100      60   10
# 23      100      80   10
# 24      100     100   10
#
# [50 rows x 25 columns]

# %%
df[(df['cut_count'] < 0)&(df['instance_name'] == 'RB1502008.txt')]
# Out:
#     executionId         ub_name  instance_name  alpha    n  m budget_Gamma  \
# 425        none  mip_separation  RB1502008.txt     20  150  2        20 20
# 426        none  mip_separation  RB1502008.txt     20  150  2        20 40
# 427        none  mip_separation  RB1502008.txt     20  150  2        20 60
# 428        none  mip_separation  RB1502008.txt     20  150  2        20 80
# 429        none  mip_separation  RB1502008.txt     20  150  2       20 100
# 430        none  mip_separation  RB1502008.txt     20  150  2        40 20
# 431        none  mip_separation  RB1502008.txt     20  150  2        40 40
# 432        none  mip_separation  RB1502008.txt     20  150  2        40 60
# 433        none  mip_separation  RB1502008.txt     20  150  2        40 80
# 434        none  mip_separation  RB1502008.txt     20  150  2       40 100
# 435        none  mip_separation  RB1502008.txt     20  150  2        60 20
# 436        none  mip_separation  RB1502008.txt     20  150  2        60 40
# 437        none  mip_separation  RB1502008.txt     20  150  2        60 60
# 438        none  mip_separation  RB1502008.txt     20  150  2        60 80
# 439        none  mip_separation  RB1502008.txt     20  150  2       60 100
# 440        none  mip_separation  RB1502008.txt     20  150  2        80 20
# 441        none  mip_separation  RB1502008.txt     20  150  2        80 40
# 442        none  mip_separation  RB1502008.txt     20  150  2        80 60
# 443        none  mip_separation  RB1502008.txt     20  150  2        80 80
# 444        none  mip_separation  RB1502008.txt     20  150  2       80 100
# 445        none  mip_separation  RB1502008.txt     20  150  2       100 20
# 446        none  mip_separation  RB1502008.txt     20  150  2       100 40
# 447        none  mip_separation  RB1502008.txt     20  150  2       100 60
# 448        none  mip_separation  RB1502008.txt     20  150  2       100 80
# 449        none  mip_separation  RB1502008.txt     20  150  2      100 100
# 425        none  mip_separation  RB1502008.txt     20  150  2        20 20
# 426        none  mip_separation  RB1502008.txt     20  150  2        20 40
# 427        none  mip_separation  RB1502008.txt     20  150  2        20 60
# 428        none  mip_separation  RB1502008.txt     20  150  2        20 80
# 429        none  mip_separation  RB1502008.txt     20  150  2       20 100
# 430        none  mip_separation  RB1502008.txt     20  150  2        40 20
# 431        none  mip_separation  RB1502008.txt     20  150  2        40 40
# 432        none  mip_separation  RB1502008.txt     20  150  2        40 60
# 433        none  mip_separation  RB1502008.txt     20  150  2        40 80
# 434        none  mip_separation  RB1502008.txt     20  150  2       40 100
# 435        none  mip_separation  RB1502008.txt     20  150  2        60 20
# 436        none  mip_separation  RB1502008.txt     20  150  2        60 40
# 437        none  mip_separation  RB1502008.txt     20  150  2        60 60
# 438        none  mip_separation  RB1502008.txt     20  150  2        60 80
# 439        none  mip_separation  RB1502008.txt     20  150  2       60 100
# 440        none  mip_separation  RB1502008.txt     20  150  2        80 20
# 441        none  mip_separation  RB1502008.txt     20  150  2        80 40
# 442        none  mip_separation  RB1502008.txt     20  150  2        80 60
# 443        none  mip_separation  RB1502008.txt     20  150  2        80 80
# 444        none  mip_separation  RB1502008.txt     20  150  2       80 100
# 445        none  mip_separation  RB1502008.txt     20  150  2       100 20
# 446        none  mip_separation  RB1502008.txt     20  150  2       100 40
# 447        none  mip_separation  RB1502008.txt     20  150  2       100 60
# 448        none  mip_separation  RB1502008.txt     20  150  2       100 80
# 447     -100.0     100      60   08
# 448     -100.0     100      80   08
# 449     -100.0     100     100   08
# 425     -100.0      20      20   08
# 426     -100.0      20      40   08
# 427     -100.0      20      60   08
# 428     -100.0      20      80   08
# 429     -100.0      20     100   08
# 430     -100.0      40      20   08
# 431     -100.0      40      40   08
# 432     -100.0      40      60   08
# 433     -100.0      40      80   08
# 434     -100.0      40     100   08
# 435     -100.0      60      20   08
# 436     -100.0      60      40   08
# 437     -100.0      60      60   08
# 438     -100.0      60      80   08
# 439     -100.0      60     100   08
# 440     -100.0      80      20   08
# 441     -100.0      80      40   08
# 442     -100.0      80      60   08
# 443     -100.0      80      80   08
# 444     -100.0      80     100   08
# 445     -100.0     100      20   08
# 446     -100.0     100      40   08
# 447     -100.0     100      60   08
# 448     -100.0     100      80   08
# 449     -100.0     100     100   08
#
# [50 rows x 25 columns]

# %%
df = df[((df['cut_count'] > 0)&(df['instance_name'] == 'RB1502008.txt')&(df['model']=='Wagner')) | ((df['instance_name'] == 'RB1502008.txt')&(df['model']=='Wilson')) | (df['instance_name'] != 'RB1502008.txt')]
df = df[((df['cut_count'] > 0)&(df['instance_name'] == 'RB2005010.txt')&(df['model']=='Wagner')) | ((df['instance_name'] == 'RB2005010.txt')&(df['model']=='Wilson')) | (df['instance_name'] != 'RB2005010.txt')]

# %%
print(len(df.index))
# Out:
# 15364

# %% [markdown]
# ### Round columns containing time (in seconds)

# %%
df['time_spent'] = df['time_spent'].round(2)
df['time_to_best_sol'] = df['time_to_best_sol'].round(2)

# %% [markdown]
# ### Sort data according to model, instance_name, alpha, n, m, Gamma1 and Gamma2 and set index

# %%
print('Sorting dataset...')
df = df.sort_values(['model', 'n', 'm', 'alpha', 'instance_name', 'Gamma1', 'Gamma2'])
display(df.dtypes)
df = df.set_index(['model', 'n', 'm', 'alpha', 'instance_name', 'Gamma1', 'Gamma2'])
display(df.head(6))
# Out:
# Sorting dataset...
# executionId               object
# ub_name                   object
# instance_name             object
# alpha                      int64
# n                          int64
# m                          int64
# budget_Gamma              object
# cmax                     float64
# permutation               object
# time_spent               float64
# time_to_best_sol         float64
# iterations                 int64
# num_visited_solutions      int64
# num_improvements           int64
# is_optimal                  bool
# validated                   bool
# gap                      float64
# lb                       float64
# cost                     float64
# cmax_dp                  float64
# model                     object
# cut_count                float64
# Gamma1                     int64
# Gamma2                     int64
# seq                       object
# dtype: object
#                                               executionId         ub_name  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20            none  mip_separation
#                                        40            none  mip_separation
#                                        60            none  mip_separation
#                                        80            none  mip_separation
#                                        100           none  mip_separation
#                                 40     20            none  mip_separation
#
#                                               budget_Gamma   cmax  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20            20 20  285.1
#                                        40            20 40  285.1
#                                        60            20 60  285.1
#                                        80            20 80  285.1
#                                        100          20 100  285.1
#                                 40     20            40 20  291.8
#
#                                                         permutation  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20      10 9 7 5 3 4 2 6 1 8
#                                        40      10 9 2 4 1 7 6 5 3 8
#                                        60      10 1 2 4 3 7 9 5 6 8
#                                        80      10 2 7 5 9 6 3 4 1 8
#                                        100     10 1 2 7 5 4 9 6 3 8
#                                 40     20      10 9 7 5 3 4 2 6 1 8
#
#                                                time_spent  time_to_best_sol  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20            6.34              6.34
#                                        40            0.11              0.11
#                                        60            0.08              0.08
#                                        80            0.06              0.06
#                                        100           0.06              0.06
#                                 40     20            0.04              0.04
#
#                                                iterations  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20               2
#                                        40               4
#                                        60               3
#                                        80               3
#                                        100              3
#                                 40     20               2
#
#                                                num_visited_solutions  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20                          2
#                                        40                          4
#                                        60                          3
#                                        80                          3
#                                        100                         3
#                                 40     20                          2
#
#                                                num_improvements  is_optimal  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20                     1        True
#                                        40                     3        True
#                                        60                     2        True
#                                        80                     2        True
#                                        100                    2        True
#                                 40     20                     1        True
#
#                                                validated           gap     lb  \
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20           True  0.000000e+00  285.1
#                                        40           True -1.993806e-16  285.1
#                                        60           True -1.993806e-16  285.1
#                                        80           True  0.000000e+00  285.1
#                                        100          True  1.993806e-16  285.1
#                                 40     20           True  1.948027e-16  291.8
#
#                                                 cost  cmax_dp  cut_count seq
# model  n  m alpha instance_name Gamma1 Gamma2
# Wagner 10 2 10    RB0101001.txt 20     20      285.1    285.1     -100.0  01
#                                        40      285.1    285.1     -100.0  01
#                                        60      285.1    285.1     -100.0  01
#                                        80      285.1    285.1     -100.0  01
#                                        100     285.1    285.1     -100.0  01
#                                 40     20      291.8    291.8     -100.0  01

# %% [markdown]
# ### Find missing results, for a given value of alpha, n and m

# %% [markdown]
# For a given group of alpha, n, m and budget_Gamma, there should be 10 results.
#
# First we will build a dataframe with the instances list and all required budget values.

# %%
data = []
rootfolder = os.getcwd()
jobs_folders = glob.glob(os.path.join(rootfolder, 'instances', 'robust', 'ying', 'data', '*/'), recursive=False)
for job_path in jobs_folders:
    alpha_folders = glob.glob(os.path.join(job_path, '*/'), recursive=False)
    n = job_path[job_path.find('data')+5:job_path.rfind('jobs')]
    #print('n: {}'.format(n))
    for alpha_path in alpha_folders:
        alpha = alpha_path[alpha_path.find('jobs')+5:alpha_path.rfind('%')]
        #print('alpha: {}'.format(alpha))
        instance_paths = glob.glob(os.path.join(alpha_path, '*'), recursive=False)
        for instance_path in instance_paths:
            instance_name = instance_path[instance_path.find('%')+2:]
            #print(instance_name)
            for gamma1 in [20, 40, 60, 80, 100]:
                for gamma2 in [20, 40, 60, 80, 100]:
                    for model in ['Wilson', 'Wagner']:
                        data.append([model, instance_name, alpha, n, 2, gamma1, gamma2])
df_instances = pd.DataFrame(data, columns=['model', 'instance_name', 'alpha', 'n', 'm', 'Gamma1', 'Gamma2'])
for col in df_instances:
    if col in ['alpha','n','m','Gamma1','Gamma2']:
        df_instances[col] = pd.to_numeric(df_instances[col], errors='coerce')
display(df_instances.dtypes)
df_instances = df_instances.set_index(['model', 'n', 'm', 'alpha', 'instance_name', 'Gamma1', 'Gamma2'])
display(df_instances)
# Out:
# model            object
# instance_name    object
# alpha             int64
# n                 int64
# m                 int64
# Gamma1            int64
# Gamma2            int64
# dtype: object
# Empty DataFrame
# Columns: []
# Index: [(Wilson, 100, 2, 10, RB1001001.txt, 20, 20), (Wagner, 100, 2, 10, RB1001001.txt, 20, 20), (Wilson, 100, 2, 10, RB1001001.txt, 20, 40), (Wagner, 100, 2, 10, RB1001001.txt, 20, 40), (Wilson, 100, 2, 10, RB1001001.txt, 20, 60), (Wagner, 100, 2, 10, RB1001001.txt, 20, 60), (Wilson, 100, 2, 10, RB1001001.txt, 20, 80), (Wagner, 100, 2, 10, RB1001001.txt, 20, 80), (Wilson, 100, 2, 10, RB1001001.txt, 20, 100), (Wagner, 100, 2, 10, RB1001001.txt, 20, 100), (Wilson, 100, 2, 10, RB1001001.txt, 40, 20), (Wagner, 100, 2, 10, RB1001001.txt, 40, 20), (Wilson, 100, 2, 10, RB1001001.txt, 40, 40), (Wagner, 100, 2, 10, RB1001001.txt, 40, 40), (Wilson, 100, 2, 10, RB1001001.txt, 40, 60), (Wagner, 100, 2, 10, RB1001001.txt, 40, 60), (Wilson, 100, 2, 10, RB1001001.txt, 40, 80), (Wagner, 100, 2, 10, RB1001001.txt, 40, 80), (Wilson, 100, 2, 10, RB1001001.txt, 40, 100), (Wagner, 100, 2, 10, RB1001001.txt, 40, 100), (Wilson, 100, 2, 10, RB1001001.txt, 60, 20), (Wagner, 100, 2, 10, RB1001001.txt, 60, 20), (Wilson, 100, 2, 10, RB1001001.txt, 60, 40), (Wagner, 100, 2, 10, RB1001001.txt, 60, 40), (Wilson, 100, 2, 10, RB1001001.txt, 60, 60), (Wagner, 100, 2, 10, RB1001001.txt, 60, 60), (Wilson, 100, 2, 10, RB1001001.txt, 60, 80), (Wagner, 100, 2, 10, RB1001001.txt, 60, 80), (Wilson, 100, 2, 10, RB1001001.txt, 60, 100), (Wagner, 100, 2, 10, RB1001001.txt, 60, 100), (Wilson, 100, 2, 10, RB1001001.txt, 80, 20), (Wagner, 100, 2, 10, RB1001001.txt, 80, 20), (Wilson, 100, 2, 10, RB1001001.txt, 80, 40), (Wagner, 100, 2, 10, RB1001001.txt, 80, 40), (Wilson, 100, 2, 10, RB1001001.txt, 80, 60), (Wagner, 100, 2, 10, RB1001001.txt, 80, 60), (Wilson, 100, 2, 10, RB1001001.txt, 80, 80), (Wagner, 100, 2, 10, RB1001001.txt, 80, 80), (Wilson, 100, 2, 10, RB1001001.txt, 80, 100), (Wagner, 100, 2, 10, RB1001001.txt, 80, 100), (W
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20            none  mip_separation
#                                         40            none  mip_separation
#                                         60            none  mip_separation
#                                         80            none  mip_separation
#                                         100           none  mip_separation
# ...                                                    ...             ...
# Wilson 200 2 50    RB2005010.txt 100    20            none  mip_separation
#                                         40            none  mip_separation
#                                         60            none  mip_separation
#                                         80            none  mip_separation
#                                         100           none  mip_separation
#
#                                                budget_Gamma    cmax  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20            20 20   285.1
#                                         40            20 40   285.1
#                                         60            20 60   285.1
#                                         80            20 80   285.1
#                                         100          20 100   285.1
# ...                                                     ...     ...
# Wilson 200 2 50    RB2005010.txt 100    20           100 20  9192.0
#                                         40           100 40  9192.0
#                                         60           100 60  9192.0
#                                         80           100 80  9192.0
#                                         100         100 100  9192.0
#
#                                                                                       permutation  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20                                   10 9 7 5 3 4 2 6 1 8
#                                         40                                   10 9 2 4 1 7 6 5 3 8
#                                         60                                   10 1 2 4 3 7 9 5 6 8
#                                         80                                   10 2 7 5 9 6 3 4 1 8
#                                         100                                  10 1 2 7 5 4 9 6 3 8
# ...                                                                                           ...
# Wilson 200 2 50    RB2005010.txt 100    20      73 27 150 60 83 96 113 177 184 48 158 148 109 ...
#                                         40      73 27 150 60 83 96 113 177 184 48 158 148 109 ...
#                                         60      73 27 150 60 83 96 113 177 184 48 158 148 109 ...
#                                         80      73 27 150 60 83 96 113 177 184 48 158 148 109 ...
#                                         100     73 27 150 60 83 96 113 177 184 48 158 148 109 ...
#
#                                                 time_spent  time_to_best_sol  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20            6.34              6.34
#                                         40            0.11              0.11
#                                         60            0.08              0.08
#                                         80            0.06              0.06
#                                         100           0.06              0.06
# ...                                                    ...               ...
# Wilson 200 2 50    RB2005010.txt 100    20        11273.43          11273.43
#                                         40        10169.19          10169.19
#                                         60          652.67            652.67
#                                         80         6095.16           6095.16
#                                         100         196.20            196.20
#
#                                                 iterations  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20             2.0
#                                         40             4.0
#                                         60             3.0
#                                         80             3.0
#                                         100            3.0
# ...                                                    ...
# Wilson 200 2 50    RB2005010.txt 100    20            13.0
#                                         40            12.0
#                                         60             4.0
#                                         80             9.0
#                                         100            2.0
#
#                                                 num_visited_solutions  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20                        2.0
#                                         40                        4.0
#                                         60                        3.0
#                                         80                        3.0
#                                         100                       3.0
# ...                                                               ...
# Wilson 200 2 50    RB2005010.txt 100    20                       13.0
#                                         40                       12.0
#                                         60                        4.0
#                                         80                        9.0
#                                         100                       2.0
#
#                                                 num_improvements is_optimal  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20                   1.0       True
#                                         40                   3.0       True
#                                         60                   2.0       True
#                                         80                   2.0       True
#                                         100                  2.0       True
# ...                                                          ...        ...
# Wilson 200 2 50    RB2005010.txt 100    20                  12.0       True
#                                         40                  11.0       True
#                                         60                   3.0       True
#                                         80                   8.0       True
#                                         100                  1.0       True
#
#                                                validated           gap  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20          True  0.000000e+00
#                                         40          True -1.993806e-16
#                                         60          True -1.993806e-16
#                                         80          True  0.000000e+00
#                                         100         True  1.993806e-16
# ...                                                  ...           ...
# Wilson 200 2 50    RB2005010.txt 100    20          True  1.088021e-04
#                                         40          True  0.000000e+00
#                                         60          True  0.000000e+00
#                                         80          True  0.000000e+00
#                                         100         True  0.000000e+00
#
#                                                     lb    cost  cmax_dp  \
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20       285.1   285.1    285.1
#                                         40       285.1   285.1    285.1
#                                         60       285.1   285.1    285.1
#                                         80       285.1   285.1    285.1
#                                         100      285.1   285.1    285.1
# ...                                                ...     ...      ...
# Wilson 200 2 50    RB2005010.txt 100    20      9191.0  9192.0   9192.0
#                                         40      9192.0  9192.0   9192.0
#                                         60      9192.0  9192.0   9192.0
#                                         80      9192.0  9192.0   9192.0
#                                         100     9192.0  9192.0   9192.0
#
#                                                 cut_count seq
# model  n   m alpha instance_name Gamma1 Gamma2
# Wagner 10  2 10    RB0101001.txt 20     20         -100.0  01
#                                         40         -100.0  01
#                                         60         -100.0  01
#                                         80         -100.0  01
#                                         100        -100.0  01
# ...                                                   ...  ..
# Wilson 200 2 50    RB2005010.txt 100    20         -100.0  10
#                                         40         -100.0  10
#                                         60         -100.0  10
#                                         80         -100.0  10
#                                         100        -100.0  10
#
# [15366 rows x 18 columns]

# %% [markdown]
# Now we will export to CSV a list with all rows with NaN values (missing experimental results).

# %%
missing_df = df_joined[df_joined.isnull().any(axis=1)].reset_index()[['model', 'n', 'm', 'alpha', 'instance_name', 'Gamma1', 'Gamma2']]
outputfolder = os.path.join(os.getcwd(), 'results', 'consolidated')
if not os.path.exists(outputfolder):
    os.makedirs(outputfolder)
print('Saving file on folder: ' + outputfolder)
fname = os.path.join(outputfolder, '2RPFS_Cmax_missing_results.csv')
missing_df.to_csv(fname, sep=';')
print('Saved: ' + fname)
# Out:
# Saving file on folder: /public/doutorado_files/2RPFS_Cmax_Budget/results/consolidated
# Saved: /public/doutorado_files/2RPFS_Cmax_Budget/results/consolidated/2RPFS_Cmax_missing_results.csv

# %%
df_grouped = df.groupby(['alpha', 'n', 'm', 'budget_Gamma']).agg({'executionId' : ['count']}).reset_index()
df_grouped.columns = [ ' '.join(str(i) for i in col) for col in df_grouped.columns]
#df_grouped.reset_index(inplace=True)
df_grouped
# Out:
#      alpha    n   m  budget_Gamma   executionId count
# 0        10   10   2       100 100                 20
# 1        10   10   2        100 20                 20
# 2        10   10   2        100 40                 20
# 3        10   10   2        100 60                 20
# 4        10   10   2        100 80                 20
# ..      ...  ...  ..           ...                ...
# 745      50  200   2        80 100                 21
# 746      50  200   2         80 20                 21
# 747      50  200   2         80 40                 21
# 748      50  200   2         80 60                 21
# 749      50  200   2         80 80                 20
#
# [750 rows x 5 columns]

# %%
table = pd.pivot_table(df, values='executionId', index=['alpha', 'n'], columns=['Gamma1', 'Gamma2'], aggfunc='count', fill_value=0)
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(table)
# Out:
# Gamma1    20                  40                  60                  80       \
# Gamma2    20  40  60  80  100 20  40  60  80  100 20  40  60  80  100 20  40
# alpha n
# 10    10   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
# 20    10   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  19  20  20  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
# 30    10   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
# 40    10   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       100  21  21  21  21  21  21  21  21  21  21  21  20  20  20  20  20  20
#       150  22  22  21  21  21  21  21  21  21  21  21  21  21  21  21  21  21
#       200  24  25  25  25  25  25  24  23  23  23  23  23  23  23  23  24  23
# 50    10   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       100  28  28  28  28  27  27  27  27  27  27  27  27  27  27  27  27  27
#       150  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20  20
#       200  24  24  24  25  24  25  25  24  23  23  24  23  23  22  22  21  21
#
# Gamma1                100
# Gamma2    60  80  100 20  40  60  80  100
# alpha n
# 10    10   20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20
# 20    10   20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20
# 30    10   20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20
#       150  20  20  20  20  20  20  20  20
#       200  20  20  20  20  20  20  20  20
# 40    10   20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20
#       100  20  20  20  20  20  20  20  20
#       150  21  21  21  21  21  21  21  21
#       200  23  23  23  23  23  23  23  23
# 50    10   20  20  20  20  20  20  20  20
#       20   20  20  20  20  20  20  20  20
#       50   20  20  20  20  20  20  20  20
#       100  27  27  27  27  27  27  27  27
#       150  20  20  20  20  20  20  20  20
#       200  21  20  21  20  20  20  20  21

# %% [markdown]
# ### Export the dataset to CSV file

# %%
# %%time

print('Saving file on folder: ' + outputfolder)
fname = os.path.join(outputfolder, '2RPFS_Cmax_all_results.csv')
df.to_csv(fname, sep=';')
print('Saved: ' + fname)
# Out:
# Saving file on folder: /public/doutorado_files/2RPFS_Cmax_Budget/results/consolidated
# Saved: /public/doutorado_files/2RPFS_Cmax_Budget/results/consolidated/2RPFS_Cmax_all_results.csv
# CPU times: user 762 ms, sys: 60.8 ms, total: 823 ms
# Wall time: 1.81 s
